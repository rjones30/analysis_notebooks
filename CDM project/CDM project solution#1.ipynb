# %% [markdown]
# # Code Division Multiplexing: HTC Tutorial using Jupyter notebooks
#
# ## Student project in High Throughput Computing
#
# <br>Netid: rtj02001
# <br>Started: March 29, 2022
# <p>I certify that this notebook was filled in by me, and represents my own original work.
# <br>Signed: Richard T. Jones

# %% [markdown]
# ## Introduction
# This project explores the power of code-division multiplexing to encode a message within the correlations between the samples of an otherwise purely random and uncorrelated time series. The final goal is to discover the hidden messages that are found somewhere within a signal provided to you by a third party. The CDM scheme that was used to encode these messages is provided to you in the form of an object froom a python class called CDMcode. This object contains a set of 17 codes, any two of which may have been used to encode the secret messages. Each code is its own sequence of +1 and -1 values which appear to be random and uncorrelated within the code, but which is repeated on top of noise within the signal, and can be discovered by computing the covariance of the signal with each code.
#
# To get started, let's generate a random signal, and represent it by a python array of integers containing values in the interval \[-128, +128). To efficiently work with arrays in this project, we will use the numpy library that has lots of features for efficiently working with arrays. In numpy, integers in the range \[-128, +128) are called bytes.

# %%
import numpy as np
arr = np.array(np.random.normal(10, 3, 100000), dtype=np.byte)

# %% [markdown]
# The first line imports the numpy math library into our project. The second line uses numpy, denoted by the short-hand "np", to generate an array of 1000 bytes named arr. Each element of arr is filled with a value drawn from a normal distribution of integers with mean value 10 and standard deviation 3. The next cell plots the array, first as a time series, then as a frequency plot of signal values. Play with the parameters in the above cell and rerun the plot cell to see how the results change. What happens if you try to increase the signal above the upper limit of 128 for byte values?

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
p1 = axes[0].plot(arr[:100])
axes[0].set_xlabel('series index')
axes[0].set_ylabel('signal')
p2 = axes[1].hist(arr, 30, (0, max(30, max(arr) * 1.1)))
axes[1].set_xlabel('signal amplitude')
axes[1].set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# Let's introduce a bunch of basic functionality for handling CDM signals by importing a custom python object class called CDMcode. Each time you construct a new object of this class, you get a complete set of codes for multiplexing messages from different channels into a combined signal at the transmitter, and for demultiplexing messages to different channels from the combined signal at the receiver. The process of multiplexing is called "encoding", and demultiplexing is called "decoding".

# %%
import numpy as np

class CDMcode:
    def __init__(self, log2length):
        """
        Constructs a new CDMcode object of length 2**log2length.
        Initialize the first code to a random bit string, and the
        subsequent log2length codes to the complete set of codes
        that are orthogonal to the first.
        """
        self.codelen = 1 << log2length
        arr = np.random.randint(2, size=self.codelen)
        code0 = np.array(arr, dtype=int)
        count = np.arange(self.codelen, dtype=int)
        self.code = [code0]
        self.coda = [2 * code0 - 1]
        self.codi = [-2 * code0 + 1]
        self.coda8 = [np.array(self.coda[0], dtype=np.byte)]
        self.codi8 = [np.array(self.codi[0], dtype=np.byte)]
        for n in range(log2length):
            coden = np.bitwise_xor(code0, (count >> n) & 1)
            self.code.append(coden)
            self.coda.append(2 * coden - 1)
            self.codi.append(-2 * coden + 1)
            self.coda8.append(np.array(self.coda[-1], dtype=np.byte))
            self.codi8.append(np.array(self.codi[-1], dtype=np.byte))
        self.codasum = [np.sum(coda) for coda in self.coda]
    
    def encode(self, message, chan):
        """
        Takes in a message bytestring and expands it into a signal
        array encoded using the code for channel chan, returning it
        as a numpy array of byte containing the bit values of the
        encoded message, length = len(message) * codelen * 8. The
        bit order in the encoded signal is big-endian.
        """
        bitstream = []
        for mbyte in message:
            for mbit in reversed(range(8)):
                if (mbyte >> mbit) % 2 == 0:
                    bitstream.append(self.codi8[chan])
                else:
                    bitstream.append(self.coda8[chan])
        return np.concatenate(bitstream)

    def decode(self, signal, chan, amp=1):
        """
        Takes in a signal array of bytes and decode any messages found
        in code channel chan. Null bits in the signal are treated as
        message termination. Valid message bits are expected to occur
        in sequences of 8 bits, otherwise a warning message is printed.
        The amplitude of the encoded signal is assumed to be amp.
        """
        dotmean = np.sum(signal) * self.codasum[chan] / len(signal)
        pthresh = dotmean + self.codelen * amp / 2
        nthresh = dotmean - self.codelen * amp / 2
        message = bytearray()
        pos = 0
        while pos + 8 * self.codelen <= len(signal):
            mbyte = 0
            for mbit in reversed(range(8)):
                sdotc = self.dot(signal[pos:], chan)
                if sdotc > pthresh:
                    mbyte += (1 << mbit)
                elif sdotc > nthresh:
                    if mbit != 7:
                        print("CDMcode.decode warning:",
                              "incomplete character found at position",
                              pos / self.codelen)
                    return bytes(message)
                pos += self.codelen
            message.append(mbyte)
        return bytes(message)
    
    def dot(self, signal, chan):
        """
        Take the inner product between the array signal[:codelen]
        and the code for channel chan. The signal array is assumed to
        be at least of length codelen.
        """
        return np.dot(self.coda[chan], signal[:self.codelen])

# %% [markdown]
# ###### Warm-up
# For simplicity, the CDMcode class assumes that the cdm codes are a power of 2 in length. This same power of 2 is what limits the total number of separate channels that can be multiplexed on a signal using this CDMcode object. This power is passed as an argument to the constructor. For example, CDMcode(5) would produce a CDMcode object that implements a cdm scheme with 6 (5 + 1) separate channels and a code length of 32. In this simple example, we set up such a scheme with 6 channels, and transmit a simple message over channel 2.

# %%
cdm = CDMcode(5)
signal = cdm.encode(b"Hello, world!", 2)
print("signal is a time series with", len(signal), "bytes.")
# Out:
# signal is a time series with 3328 bytes.

# %% [markdown]
# Now lets cycle through all 6 channels and see if we can find the one that has the message encoded on it. Play around with the above encoding. Add an offset to the signal, and try adding some random background noise. Is the algorithm still able to detect the correct message on the right channel? At what point does the noise start to interfere with the fidelity of the message?

# %%
for chan in range(6):
    msg = cdm.decode(signal, chan)
    if len(msg) > 0:
        print("found a message on channel", chan, msg)
# Out:
# found a message on channel 2 b'Hello, world!'

# %% [markdown]
# ## The challenge problem
# Now it is time to tackle the main challenge of this project. You have been given a signal stored in a plain text file found in your notebook directory. The file has a name like cdm_signal_N.csv where N is some small integer that the instructor uses to identify which signal you have been assigned to study. The CDMcode object that was used to encode secret messages into this signal is also stored in the same project directory under the name cdm_codes_N.dat. Use code like the following to load this CDMcode object into your project workspace. You will need to replace the symbol N in the filename with the specific number you were given.

# %%
import pickle
cdm = pickle.load(open("cdm_codes_1.dat", "rb"))
print("loaded CDMcode object with code length", cdm.codelen)
# Out:
# loaded CDMcode object with code length 65536

# %% [markdown]
# The rest of this project is for you to work out. The general steps you need to complete are as follows.
# <ol>
#     <li>Open the input text file and read in the signal values, loading them into a numpy byte array in your notebook.</li>
#     <li>Search through the signal for the start of a message. Messages can start at any arbitrary place in the signal, so you need to measure the correlation of the code for each channel with the signal starting at all possible offsets, and look for a non-random correlation that indicates where the message starts.</li>
#     <li>Once you have found the beginning of a message on any channel, extract the message until the correlation vanishes. There is at most one message on any given channel, so once you have seen a message terminate, there is no need to continue to search the signal on that channel.</li>
#     <li>Divide your notebook up into sections, with text blocks ahead of each code block explaining what the code block is intended to do.</li>
#     <li>Your last cell in the notebook should be the one where you tell what messages you have found, what channels they were transmitted on, and what their offsets into the signal were.
#         </ol>

# %% [markdown]
# # Solution to input dataset 1

# %% [markdown]
# Read in the CDMcode and signal for dataset 1 into objects in memory.

# %%
cdm = pickle.load(open("cdm_codes_1.dat", "rb"))
infile = open("cdm_signal_1.csv", "r")
sectlen = 1000000
sects = []
while True:
    sect = np.array([0] * sectlen, dtype=np.byte)
    i = 0
    while i < sectlen:
        try:
            line = next(infile)
            sect[i] = int(line[:-1])
        except:
            break
        i += 1
    sects.append(sect[:i])
    print(len(sects), i)
    if i < sectlen:
        break
signal = np.concatenate(sects)
# Out:
# 1 1000000
# 2 1000000
# 3 1000000
# 4 1000000
# 5 1000000
# 6 1000000
# 7 1000000
# 8 1000000
# 9 1000000
# 10 1000000
# 11 1000000
# 12 1000000
# 13 1000000
# 14 1000000
# 15 1000000
# 16 1000000
# 17 1000000
# 18 1000000
# 19 1000000
# 20 1000000
# 21 1000000
# 22 1000000
# 23 1000000
# 24 1000000
# 25 1000000
# 26 1000000
# 27 1000000
# 28 1000000
# 29 1000000
# 30 1000000
# 31 1000000
# 32 1000000
# 33 1000000
# 34 1000000
# 35 1000000
# 36 1000000
# 37 1000000
# 38 1000000
# 39 1000000
# 40 1000000
# 41 1000000
# 42 1000000
# 43 1000000
# 44 1000000
# 45 1000000
# 46 1000000
# 47 1000000
# 48 1000000
# 49 1000000
# 50 1000000
# 51 1000000
# 52 1000000
# 53 1000000
# 54 1000000
# 55 1000000
# 56 1000000
# 57 1000000
# 58 1000000
# 59 1000000
# 60 1000000
# 61 1000000
# 62 1000000
# 63 1000000
# 64 1000000
# 65 1000000
# 66 1000000
# 67 1000000
# 68 1000000
# 69 1000000
# 70 1000000
# 71 1000000
# 72 1000000
# 73 1000000
# 74 1000000
# 75 1000000
# 76 1000000
# 77 1000000
# 78 1000000
# 79 1000000
# 80 1000000
# 81 1000000
# 82 1000000
# 83 1000000
# 84 1000000
# 85 1000000
# 86 1000000
# 87 1000000
# 88 1000000
# 89 1000000
# 90 1000000
# 91 1000000
# 92 1000000
# 93 1000000
# 94 1000000
# 95 1000000
# 96 1000000
# 97 1000000
# 98 1000000
# 99 1000000
# 100 1000000
# 101 1000000
# 102 1000000
# 103 1000000
# 104 1000000
# 105 1000000
# 106 1000000
# 107 1000000
# 108 1000000
# 109 1000000
# 110 1000000
# 111 1000000
# 112 1000000
# 113 1000000
# 114 1000000
# 115 1000000
# 116 1000000
# 117 1000000
# 118 1000000
# 119 1000000
# 120 1000000
# 121 1000000
# 122 1000000
# 123 1000000
# 124 1000000
# 125 1000000
# 126 1000000
# 127 1000000
# 128 1000000
# 129 1000000
# 130 1000000
# 131 1000000
# 132 1000000
# 133 1000000
# 134 1000000
# 135 1000000
# 136 1000000
# 137 1000000
# 138 1000000
# 139 1000000
# 140 1000000
# 141 1000000
# 142 1000000
# 143 1000000
# 144 1000000
# 145 1000000
# 146 1000000
# 147 1000000
# 148 1000000
# 149 1000000
# 150 1000000
# 151 1000000
# 152 1000000
# 153 1000000
# 154 1000000
# 155 1000000
# 156 1000000
# 157 1000000
# 158 1000000
# 159 1000000
# 160 1000000
# 161 1000000
# 162 1000000
# 163 1000000
# 164 1000000
# 165 1000000
# 166 1000000
# 167 1000000
# 168 1000000
# 169 1000000
# 170 1000000
# 171 1000000
# 172 1000000
# 173 1000000
# 174 1000000
# 175 1000000
# 176 1000000
# 177 1000000
# 178 1000000
# 179 1000000
# 180 1000000
# 181 1000000
# 182 1000000
# 183 1000000
# 184 1000000
# 185 1000000
# 186 1000000
# 187 1000000
# 188 1000000
# 189 1000000
# 190 1000000
# 191 1000000
# 192 1000000
# 193 1000000
# 194 1000000
# 195 1000000
# 196 1000000
# 197 1000000
# 198 1000000
# 199 1000000
# 200 1000000
# 201 1000000
# 202 1000000
# 203 1000000
# 204 1000000
# 205 1000000
# 206 1000000
# 207 1000000
# 208 1000000
# 209 1000000
# 210 1000000
# 211 1000000
# 212 1000000
# 213 1000000
# 214 1000000
# 215 1000000
# 216 1000000
# 217 1000000
# 218 1000000
# 219 1000000
# 220 1000000
# 221 1000000
# 222 1000000
# 223 1000000
# 224 1000000
# 225 1000000
# 226 1000000
# 227 1000000
# 228 1000000
# 229 1000000
# 230 1000000
# 231 1000000
# 232 1000000
# 233 1000000
# 234 1000000
# 235 1000000
# 236 1000000
# 237 1000000
# 238 1000000
# 239 1000000
# 240 1000000
# 241 1000000
# 242 1000000
# 243 1000000
# 244 1000000
# 245 1000000
# 246 1000000
# 247 1000000
# 248 1000000
# 249 1000000
# 250 1000000
# 251 1000000
# 252 1000000
# 253 1000000
# 254 1000000
# 255 1000000
# 256 1000000
# 257 1000000
# 258 1000000
# 259 1000000
# 260 1000000
# 261 1000000
# 262 1000000
# 263 1000000
# 264 1000000
# 265 1000000
# 266 1000000
# 267 1000000
# 268 1000000
# 269 1000000
# 270 1000000
# 271 1000000
# 272 1000000
# 273 1000000
# 274 1000000
# 275 1000000
# 276 1000000
# 277 1000000
# 278 1000000
# 279 1000000
# 280 1000000
# 281 1000000
# 282 1000000
# 283 1000000
# 284 1000000
# 285 1000000
# 286 1000000
# 287 1000000
# 288 1000000
# 289 1000000
# 290 1000000
# 291 1000000
# 292 1000000
# 293 1000000
# 294 1000000
# 295 1000000
# 296 1000000
# 297 1000000
# 298 1000000
# 299 1000000
# 300 1000000
# 301 1000000
# 302 1000000
# 303 1000000
# 304 1000000
# 305 1000000
# 306 1000000
# 307 1000000
# 308 1000000
# 309 1000000
# 310 1000000
# 311 1000000
# 312 1000000
# 313 1000000
# 314 1000000
# 315 1000000
# 316 1000000
# 317 1000000
# 318 1000000
# 319 1000000
# 320 1000000
# 321 1000000
# 322 1000000
# 323 1000000
# 324 1000000
# 325 1000000
# 326 1000000
# 327 1000000
# 328 1000000
# 329 1000000
# 330 1000000
# 331 1000000
# 332 1000000
# 333 1000000
# 334 1000000
# 335 1000000
# 336 1000000
# 337 1000000
# 338 1000000
# 339 1000000
# 340 1000000
# 341 1000000
# 342 1000000
# 343 1000000
# 344 1000000
# 345 1000000
# 346 1000000
# 347 1000000
# 348 1000000
# 349 1000000
# 350 1000000
# 351 1000000
# 352 1000000
# 353 1000000
# 354 1000000
# 355 1000000
# 356 1000000
# 357 1000000
# 358 1000000
# 359 1000000
# 360 1000000
# 361 1000000
# 362 1000000
# 363 1000000
# 364 1000000
# 365 1000000
# 366 1000000
# 367 1000000
# 368 1000000
# 369 1000000
# 370 1000000
# 371 690700

# %% [markdown]
# ## define a fast scanner function

# %%
def scan(self, signal, chan, amp=1, sig=6):
    """
    Scan the signal, one sample at a time, searching for the start of the
    code for channel chan. The scan stops as soon as the start of the code
    is found, or a total of codelen bits has been scanned. The return value
    is the offset [0,codelen) of the start of the code, or -1 if not found.
    This algorithm is equivalent to a loop calling decode(signal[i:],chan)
    for i in range(codelen), but it has been optimized for efficiency. It
    is assumed that signal is at least 2 * codelen in length, otherwise it
    would make no sense to scan it.
    """
    sigmean = np.mean(signal[:2*self.codelen])
    sigvari = np.var(signal[:2*self.codelen])
    ndiscrim = int(sigvari * (2 * sig / amp)**2)
    if ndiscrim > self.codelen:
        print("Warning in CDMcode_scanner.scan -",
              "codelen insufficient to guarantee noise suppression",
              "at the requested level of {0} sigma,".format(sig),
              "continuing on a best-effort basis.")
        ndiscrim = self.codelen
    thresh = sig * (ndiscrim * sigvari)**0.5
    dotbase = np.sum(self.coda[chan][:ndiscrim]) * sigmean
    for offset in range(self.codelen):
        sdotc = np.dot(signal[offset:offset+ndiscrim], 
                       self.coda[chan][:ndiscrim]) - dotbase
        if abs(sdotc) > thresh:
            return offset
    return -1

# %% [markdown]
# Scan the entire signal within a selected channel.

# %%
chan = 11
pos = 0
while pos < len(signal):
    offset = scan(cdm, signal[pos:], chan)
    if offset >= 0:
        print("found start of signal on channel", chan,
              "at offset", pos + offset)
        msg = cdm.decode(signal[pos + offset:], chan)
        print("message is length", len(msg), ":")
        print(msg.decode())
        break
    print("no signal so far, offset=", pos)
    pos += cdm.codelen

# %% [markdown]
# Run a spot check on all channels, skipping forward by N characters between spots.

# %%
nskip = 50
pos = 0
while pos < len(signal):
    for chan in range(17):
        offset = scan(cdm, signal[pos:], chan)
        if offset >= 0:
            print("found start of signal on channel", chan,
                  "at offset", pos + offset)
            msg = cdm.decode(signal[pos + offset:], chan)
            print("message fragment is length", len(msg))
        else:
            print("no signal so far on channel", chan, "offset", pos)
    pos += cdm.codelen * nskip * 8
# Out:
# no signal so far on channel 0 offset 0
# no signal so far on channel 1 offset 0
# no signal so far on channel 2 offset 0
# no signal so far on channel 3 offset 0
# no signal so far on channel 4 offset 0
# no signal so far on channel 5 offset 0
# no signal so far on channel 6 offset 0
# no signal so far on channel 7 offset 0
# no signal so far on channel 8 offset 0
# no signal so far on channel 9 offset 0
# no signal so far on channel 10 offset 0
# no signal so far on channel 11 offset 0
# no signal so far on channel 12 offset 0
# no signal so far on channel 13 offset 0
# no signal so far on channel 14 offset 0
# no signal so far on channel 15 offset 0
# no signal so far on channel 16 offset 0
# no signal so far on channel 0 offset 26214400
# no signal so far on channel 1 offset 26214400
# no signal so far on channel 2 offset 26214400
# no signal so far on channel 3 offset 26214400
# no signal so far on channel 4 offset 26214400
# no signal so far on channel 5 offset 26214400
# found start of signal on channel 6 at offset 26233484
# message fragment is length 92
# no signal so far on channel 7 offset 26214400
# no signal so far on channel 8 offset 26214400
# no signal so far on channel 9 offset 26214400
# no signal so far on channel 10 offset 26214400
# found start of signal on channel 11 at offset 26233484
# message fragment is length 98
# no signal so far on channel 12 offset 26214400
# no signal so far on channel 13 offset 26214400
# no signal so far on channel 14 offset 26214400
# no signal so far on channel 15 offset 26214400
# no signal so far on channel 16 offset 26214400
# no signal so far on channel 0 offset 52428800
# no signal so far on channel 1 offset 52428800
# no signal so far on channel 2 offset 52428800
# no signal so far on channel 3 offset 52428800
# no signal so far on channel 4 offset 52428800
# no signal so far on channel 5 offset 52428800
# found start of signal on channel 6 at offset 52447884
# message fragment is length 42
# no signal so far on channel 7 offset 52428800
# no signal so far on channel 8 offset 52428800
# no signal so far on channel 9 offset 52428800
# no signal so far on channel 10 offset 52428800
# found start of signal on channel 11 at offset 52447884
# message fragment is length 48
# no signal so far on channel 12 offset 52428800
# no signal so far on channel 13 offset 52428800
# no signal so far on channel 14 offset 52428800
# no signal so far on channel 15 offset 52428800
# no signal so far on channel 16 offset 52428800
# no signal so far on channel 0 offset 78643200
# no signal so far on channel 1 offset 78643200
# no signal so far on channel 2 offset 78643200
# no signal so far on channel 3 offset 78643200
# no signal so far on channel 4 offset 78643200
# no signal so far on channel 5 offset 78643200
# no signal so far on channel 6 offset 78643200
# no signal so far on channel 7 offset 78643200
# no signal so far on channel 8 offset 78643200
# no signal so far on channel 9 offset 78643200
# no signal so far on channel 10 offset 78643200
# no signal so far on channel 11 offset 78643200
# no signal so far on channel 12 offset 78643200
# no signal so far on channel 13 offset 78643200
# no signal so far on channel 14 offset 78643200
# no signal so far on channel 15 offset 78643200
# no signal so far on channel 16 offset 78643200
# no signal so far on channel 0 offset 104857600
# no signal so far on channel 1 offset 104857600
# no signal so far on channel 2 offset 104857600
# no signal so far on channel 3 offset 104857600
# no signal so far on channel 4 offset 104857600
# no signal so far on channel 5 offset 104857600
# no signal so far on channel 6 offset 104857600
# no signal so far on channel 7 offset 104857600
# no signal so far on channel 8 offset 104857600
# no signal so far on channel 9 offset 104857600
# no signal so far on channel 10 offset 104857600
# no signal so far on channel 11 offset 104857600
# no signal so far on channel 12 offset 104857600
# no signal so far on channel 13 offset 104857600
# no signal so far on channel 14 offset 104857600
# no signal so far on channel 15 offset 104857600
# no signal so far on channel 16 offset 104857600
# no signal so far on channel 0 offset 131072000
# no signal so far on channel 1 offset 131072000
# no signal so far on channel 2 offset 131072000
# no signal so far on channel 3 offset 131072000
# no signal so far on channel 4 offset 131072000
# no signal so far on channel 5 offset 131072000
# no signal so far on channel 6 offset 131072000
# no signal so far on channel 7 offset 131072000
# no signal so far on channel 8 offset 131072000
# no signal so far on channel 9 offset 131072000
# no signal so far on channel 10 offset 131072000
# no signal so far on channel 11 offset 131072000
# no signal so far on channel 12 offset 131072000
# no signal so far on channel 13 offset 131072000
# no signal so far on channel 14 offset 131072000
# no signal so far on channel 15 offset 131072000
# no signal so far on channel 16 offset 131072000
# no signal so far on channel 0 offset 157286400
# no signal so far on channel 1 offset 157286400
# no signal so far on channel 2 offset 157286400
# no signal so far on channel 3 offset 157286400
# no signal so far on channel 4 offset 157286400
# no signal so far on channel 5 offset 157286400
# no signal so far on channel 6 offset 157286400
# no signal so far on channel 7 offset 157286400
# no signal so far on channel 8 offset 157286400
# no signal so far on channel 9 offset 157286400
# no signal so far on channel 10 offset 157286400
# no signal so far on channel 11 offset 157286400
# no signal so far on channel 12 offset 157286400
# no signal so far on channel 13 offset 157286400
# no signal so far on channel 14 offset 157286400
# no signal so far on channel 15 offset 157286400
# no signal so far on channel 16 offset 157286400
# no signal so far on channel 0 offset 183500800
# no signal so far on channel 1 offset 183500800
# no signal so far on channel 2 offset 183500800
# no signal so far on channel 3 offset 183500800
# no signal so far on channel 4 offset 183500800
# no signal so far on channel 5 offset 183500800
# no signal so far on channel 6 offset 183500800
# no signal so far on channel 7 offset 183500800
# no signal so far on channel 8 offset 183500800
# no signal so far on channel 9 offset 183500800
# no signal so far on channel 10 offset 183500800
# no signal so far on channel 11 offset 183500800
# no signal so far on channel 12 offset 183500800
# no signal so far on channel 13 offset 183500800
# no signal so far on channel 14 offset 183500800
# no signal so far on channel 15 offset 183500800
# no signal so far on channel 16 offset 183500800
# no signal so far on channel 0 offset 209715200
# no signal so far on channel 1 offset 209715200
# no signal so far on channel 2 offset 209715200
# no signal so far on channel 3 offset 209715200
# no signal so far on channel 4 offset 209715200
# no signal so far on channel 5 offset 209715200
# no signal so far on channel 6 offset 209715200
# no signal so far on channel 7 offset 209715200
# no signal so far on channel 8 offset 209715200
# no signal so far on channel 9 offset 209715200
# no signal so far on channel 10 offset 209715200
# no signal so far on channel 11 offset 209715200
# no signal so far on channel 12 offset 209715200
# no signal so far on channel 13 offset 209715200
# no signal so far on channel 14 offset 209715200
# no signal so far on channel 15 offset 209715200
# no signal so far on channel 16 offset 209715200
# no signal so far on channel 0 offset 235929600
# no signal so far on channel 1 offset 235929600
# no signal so far on channel 2 offset 235929600
# no signal so far on channel 3 offset 235929600
# no signal so far on channel 4 offset 235929600
# no signal so far on channel 5 offset 235929600
# no signal so far on channel 6 offset 235929600
# no signal so far on channel 7 offset 235929600
# no signal so far on channel 8 offset 235929600
# no signal so far on channel 9 offset 235929600
# no signal so far on channel 10 offset 235929600
# no signal so far on channel 11 offset 235929600
# no signal so far on channel 12 offset 235929600
# no signal so far on channel 13 offset 235929600
# no signal so far on channel 14 offset 235929600
# no signal so far on channel 15 offset 235929600
# no signal so far on channel 16 offset 235929600
# no signal so far on channel 0 offset 262144000
# no signal so far on channel 1 offset 262144000
# no signal so far on channel 2 offset 262144000
# no signal so far on channel 3 offset 262144000
# no signal so far on channel 4 offset 262144000
# no signal so far on channel 5 offset 262144000
# no signal so far on channel 6 offset 262144000
# no signal so far on channel 7 offset 262144000
# no signal so far on channel 8 offset 262144000
# no signal so far on channel 9 offset 262144000
# no signal so far on channel 10 offset 262144000
# no signal so far on channel 11 offset 262144000
# no signal so far on channel 12 offset 262144000
# no signal so far on channel 13 offset 262144000
# no signal so far on channel 14 offset 262144000
# no signal so far on channel 15 offset 262144000
# no signal so far on channel 16 offset 262144000
# no signal so far on channel 0 offset 288358400
# no signal so far on channel 1 offset 288358400
# no signal so far on channel 2 offset 288358400
# no signal so far on channel 3 offset 288358400
# no signal so far on channel 4 offset 288358400
# no signal so far on channel 5 offset 288358400
# no signal so far on channel 6 offset 288358400
# no signal so far on channel 7 offset 288358400
# no signal so far on channel 8 offset 288358400
# no signal so far on channel 9 offset 288358400
# no signal so far on channel 10 offset 288358400
# no signal so far on channel 11 offset 288358400
# no signal so far on channel 12 offset 288358400
# no signal so far on channel 13 offset 288358400
# no signal so far on channel 14 offset 288358400
# no signal so far on channel 15 offset 288358400
# no signal so far on channel 16 offset 288358400
# no signal so far on channel 0 offset 314572800
# no signal so far on channel 1 offset 314572800
# no signal so far on channel 2 offset 314572800
# no signal so far on channel 3 offset 314572800
# no signal so far on channel 4 offset 314572800
# no signal so far on channel 5 offset 314572800
# no signal so far on channel 6 offset 314572800
# no signal so far on channel 7 offset 314572800
# no signal so far on channel 8 offset 314572800
# no signal so far on channel 9 offset 314572800
# no signal so far on channel 10 offset 314572800
# no signal so far on channel 11 offset 314572800
# no signal so far on channel 12 offset 314572800
# no signal so far on channel 13 offset 314572800
# no signal so far on channel 14 offset 314572800
# no signal so far on channel 15 offset 314572800
# no signal so far on channel 16 offset 314572800
# no signal so far on channel 0 offset 340787200
# no signal so far on channel 1 offset 340787200
# no signal so far on channel 2 offset 340787200
# no signal so far on channel 3 offset 340787200
# no signal so far on channel 4 offset 340787200
# no signal so far on channel 5 offset 340787200
# no signal so far on channel 6 offset 340787200
# no signal so far on channel 7 offset 340787200
# no signal so far on channel 8 offset 340787200
# no signal so far on channel 9 offset 340787200
# no signal so far on channel 10 offset 340787200
# no signal so far on channel 11 offset 340787200
# no signal so far on channel 12 offset 340787200
# no signal so far on channel 13 offset 340787200
# no signal so far on channel 14 offset 340787200
# no signal so far on channel 15 offset 340787200
# no signal so far on channel 16 offset 340787200
# no signal so far on channel 0 offset 367001600
# no signal so far on channel 1 offset 367001600
# no signal so far on channel 2 offset 367001600
# no signal so far on channel 3 offset 367001600
# no signal so far on channel 4 offset 367001600
# no signal so far on channel 5 offset 367001600
# no signal so far on channel 6 offset 367001600
# no signal so far on channel 7 offset 367001600
# no signal so far on channel 8 offset 367001600
# no signal so far on channel 9 offset 367001600
# no signal so far on channel 10 offset 367001600
# no signal so far on channel 11 offset 367001600
# no signal so far on channel 12 offset 367001600
# no signal so far on channel 13 offset 367001600
# no signal so far on channel 14 offset 367001600
# no signal so far on channel 15 offset 367001600
# no signal so far on channel 16 offset 367001600
